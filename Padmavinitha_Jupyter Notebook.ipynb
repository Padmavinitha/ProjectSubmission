# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Padmavinitha Venkateshwaran__
#
# Data Scientist

# %% [markdown]
# _I am interested in Data science because it helps make the business decicions better and clear based on the data available. It also helps in understanding the customer needs and serve better._

# %% [markdown]
# ### The below code should print the sum of five numbers

# %%
#define a function for addition
def add(a, b, c, d, e):
    return a + b + c + d + e

val = add(5, 5, 5, 5, 5)

val
# Out:
# 25

# %% [markdown]
# 1. Hyperlink - https://en.wikipedia.org/wiki/Data_science
#
#
# 2. strikethrough -
# <strike>This is a sample for strike text</strike>
# <del>strike text<del>
#
#
# 3. Image - ![DataScience.png](attachment:e799966c-39cd-42ee-848c-fa43694f10dc.png)
